# %%
import pandas as pd

df=pd.read_csv(
    'products/MCC/raw/MCC_DataExport_pre-biased-transistors(MCC-pre-biased-transistors).csv',
    header=0,
    skiprows=[0,2]
)
df.columns = [' '.join(col.split()) for col in df.columns]
print(df.mean(numeric_only=True).round(2))
df.info()
# Out:
# R1 Typ (KΩ)       14.62
# R2 Typ (KΩ)       27.54
# fT(MHz)          233.74
# PD(mW)           172.47
# Tj [max] (°C)    150.00
# dtype: float64
# <class 'pandas.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacture          248 non-null    str
#  1   Product              248 non-null    str
#  2   Status               248 non-null    str
#  3   Compliance           248 non-null    str
#  4   Number of Functions  248 non-null    str
#  5   Polarity             248 non-null    str
#  6   Package Type         248 non-null    str
#  7   IO(mA)               248 non-null    str
#  8   R1 Typ (KΩ)          248 non-null    float64
#  9   R2 Typ (KΩ)          223 non-null    float64
#  10  VCC(V)               248 non-null    str
#  11  fT(MHz)              247 non-null    float64
#  12  PD(mW)               248 non-null    int64
# ...

# %%
df.head(10)
# Out:
#                          Manufacture    Product     Status Compliance  \
# 0  MCC (Micro Commercial Components)  UMH15NHE3  Preferred      A R H
# 1  MCC (Micro Commercial Components)       EMH9     Active        R H
# 2  MCC (Micro Commercial Components)    UMH31NS     Active        R H
# 3  MCC (Micro Commercial Components)       EMH1     Active        R H
# 4  MCC (Micro Commercial Components)     IMH31N     Active        R H
# 5  MCC (Micro Commercial Components)      EMH10     Active        R H
# 6  MCC (Micro Commercial Components)      UMH1N     Active        R H
# 7  MCC (Micro Commercial Components)      UMH2N     Active        R H
# 8  MCC (Micro Commercial Components)      EMH11     Active        R H
# 9  MCC (Micro Commercial Components)      EMH13     Active        R H
#
#   Number of Functions Polarity Package Type IO(mA)  R1 Typ (KΩ)  R2 Typ (KΩ)  \
# 0         Dual(R1/R2)    NPN*2      SOT-363    100          4.7          4.7
# ...

# %%
df2=pd.read_csv(
    'products/MCC/clean/MCC_DataExport_pre-biased-transistors(MCC-pre-biased-transistors).csv',
    header=0
)

print(df2.mean(numeric_only=True).round(2))
df2.info()
# Out:
# R1 Typ (KΩ)       14.62
# R2 Typ (KΩ)       27.54
# fT(MHz)          233.74
# PD(mW)           172.47
# Tj [max] (°C)    150.00
# dtype: float64
# <class 'pandas.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacture          248 non-null    str
#  1   Product              248 non-null    str
#  2   Status               248 non-null    str
#  3   Compliance           248 non-null    str
#  4   Number of Functions  248 non-null    str
#  5   Polarity             248 non-null    str
#  6   Package Type         248 non-null    str
#  7   IO(mA)               248 non-null    str
#  8   R1 Typ (KΩ)          248 non-null    float64
#  9   R2 Typ (KΩ)          223 non-null    float64
#  10  VCC(V)               248 non-null    str
#  11  fT(MHz)              247 non-null    float64
#  12  PD(mW)               248 non-null    int64
# ...

# %%
df2.head(10)
# Out:
#                          Manufacture    Product     Status Compliance  \
# 0  MCC (Micro Commercial Components)  UMH15NHE3  Preferred      A R H
# 1  MCC (Micro Commercial Components)       EMH9     Active        R H
# 2  MCC (Micro Commercial Components)    UMH31NS     Active        R H
# 3  MCC (Micro Commercial Components)       EMH1     Active        R H
# 4  MCC (Micro Commercial Components)     IMH31N     Active        R H
# 5  MCC (Micro Commercial Components)      EMH10     Active        R H
# 6  MCC (Micro Commercial Components)      UMH1N     Active        R H
# 7  MCC (Micro Commercial Components)      UMH2N     Active        R H
# 8  MCC (Micro Commercial Components)      EMH11     Active        R H
# 9  MCC (Micro Commercial Components)      EMH13     Active        R H
#
#   Number of Functions Polarity Package Type IO(mA)  R1 Typ (KΩ)  R2 Typ (KΩ)  \
# 0         Dual(R1/R2)    NPN*2      SOT-363    100          4.7          4.7
# ...
