# %%
import pandas as pd

df=pd.read_csv(
    'products/MCC/raw/MCC_DataExport_bridge-rectifiers(MCC-bridge-rectifiers).csv',
    header=0,
    skiprows=[0,2]
)

df.columns = [' '.join(col.split()) for col in df.columns]
print(df.mean(numeric_only=True).round(2))
df.info()
# Out:
# IF(AV)(A)              15.96
# VRWM (V)              856.40
# VF (V) [max]@IF(A)      1.06
# IR (uA) [max] @ VR     10.27
# IFSM (A)              224.47
# IF(A)                   8.00
# VR (V)                856.40
# Tj [max] (°C)         149.59
# dtype: float64
# <class 'pandas.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacture          422 non-null    str
#  1   Product              422 non-null    str
#  2   Status               422 non-null    str
#  3   Compliance           422 non-null    str
#  4   Number of Functions  422 non-null    str
#  5   Package Type         422 non-null    str
#  6   IF(AV)(A)            422 non-null    float64
#  7   VRWM (V)             422 non-null    int64
#  8   VF (V) [max]@IF(A)   422 non-null    float64
#  9   IR (uA) [max] @ VR   422 non-null    int64
# ...

# %%
df.head(10)
# Out:
#                          Manufacture   Product     Status Compliance  \
# 0  MCC (Micro Commercial Components)   GBU1016  Preferred        R H
# 1  MCC (Micro Commercial Components)   GBU2516  Preferred        R H
# 2  MCC (Micro Commercial Components)   GBU3516  Preferred        R H
# 3  MCC (Micro Commercial Components)   GBU5016  Preferred        R H
# 4  MCC (Micro Commercial Components)   GBU3016  Preferred        R H
# 5  MCC (Micro Commercial Components)  TBL1008E  Preferred        R H
# 6  MCC (Micro Commercial Components)  TBL808EA  Preferred        R H
# 7  MCC (Micro Commercial Components)  KBJ806GL  Preferred        R H
# 8  MCC (Micro Commercial Components)  KBJ808GL  Preferred        R H
# 9  MCC (Micro Commercial Components)  KBJ2010G  Preferred        R H
#
#   Number of Functions Package Type  IF(AV)(A)  VRWM (V)  VF (V) [max]@IF(A)  \
# 0      1-Phase Bridge          GBU       10.0      1600                1.05
# ...

# %%
df2=pd.read_csv(
    'products/MCC/clean/MCC_DataExport_bridge-rectifiers(MCC-bridge-rectifiers).csv',
    header=0
)

print(df2.mean(numeric_only=True).round(2))
df2.info()
# Out:
# IF(AV)(A)              15.96
# VRWM (V)              856.40
# VF (V) [max]@IF(A)      1.06
# IR (uA) [max] @ VR     10.27
# IFSM (A)              224.47
# IF(A)                   8.00
# VR (V)                856.40
# Tj [max] (°C)         149.59
# dtype: float64
# <class 'pandas.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacture          422 non-null    str
#  1   Product              422 non-null    str
#  2   Status               422 non-null    str
#  3   Compliance           422 non-null    str
#  4   Number of Functions  422 non-null    str
#  5   Package Type         422 non-null    str
#  6   IF(AV)(A)            422 non-null    float64
#  7   VRWM (V)             422 non-null    int64
#  8   VF (V) [max]@IF(A)   422 non-null    float64
#  9   IR (uA) [max] @ VR   422 non-null    int64
# ...

# %%
df2.head(10)
# Out:
#                          Manufacture   Product     Status Compliance  \
# 0  MCC (Micro Commercial Components)   GBU1016  Preferred        R H
# 1  MCC (Micro Commercial Components)   GBU2516  Preferred        R H
# 2  MCC (Micro Commercial Components)   GBU3516  Preferred        R H
# 3  MCC (Micro Commercial Components)   GBU5016  Preferred        R H
# 4  MCC (Micro Commercial Components)   GBU3016  Preferred        R H
# 5  MCC (Micro Commercial Components)  TBL1008E  Preferred        R H
# 6  MCC (Micro Commercial Components)  TBL808EA  Preferred        R H
# 7  MCC (Micro Commercial Components)  KBJ806GL  Preferred        R H
# 8  MCC (Micro Commercial Components)  KBJ808GL  Preferred        R H
# 9  MCC (Micro Commercial Components)  KBJ2010G  Preferred        R H
#
#   Number of Functions Package Type  IF(AV)(A)  VRWM (V)  VF (V) [max]@IF(A)  \
# 0      1-Phase Bridge          GBU       10.0      1600                1.05
# ...
