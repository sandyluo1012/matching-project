# %%
import pandas as pd

df=pd.read_csv(
    'products/MCC/raw/MCC_DataExport_power-mosfets(MCC-power-mosfets).csv',
    header=0,
    skiprows=[0,2]
)
df.columns = [' '.join(col.split()) for col in df.columns]
print(df.mean(numeric_only=True))
df.info()
# Out:
# Drain-Source On-Resistance RDS(ON) Max @VGS=2.5V (Ω)      0.022118
# Junction Temperature Tj [max] (°C)                      158.589385
# dtype: float64
# <class 'pandas.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 19 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Manufacture                                           716 non-null    str
#  1   Product                                               716 non-null    str
#  2   Status                                                716 non-null    str
#  3   Compliance                                            716 non-null    str
#  4   Number of Functions                                   716 non-null    str
#  5   Channel                                               716 non-null    str
#  6   Package Type                                          716 non-null    str
# ...

# %%
df[df['Channel']=='N+P'].head(100)
# df.head(10)
# Out:
#                            Manufacture          Product     Status Compliance  \
# 36   MCC (Micro Commercial Components)     MCGD115NP10L  Preferred        R H
# 122  MCC (Micro Commercial Components)       MCGD10NP03     Active        R H
# 270  MCC (Micro Commercial Components)    MCACD032NP06L     Active        R H
# 271  MCC (Micro Commercial Components)     MCQD028NP04L     Active        R H
# 272  MCC (Micro Commercial Components)     MCQD037NP06L     Active        R H
# 273  MCC (Micro Commercial Components)    MCACD100NP10L     Active        R H
# 274  MCC (Micro Commercial Components)      MCQ200NP10L     Active        R H
# 275  MCC (Micro Commercial Components)       MCQ03NP10L     Active        R H
# 276  MCC (Micro Commercial Components)     MCGD016NP04L     Active        R H
# 277  MCC (Micro Commercial Components)     MCGD018NP03L     Active        R H
# 278  MCC (Micro Commercial Components)      MCQ018NP03L     Active        R H
# ...

# %%
df2=pd.read_csv(
    'products/MCC/clean/MCC_DataExport_power-mosfets(MCC-power-mosfets).csv',
    header=0
)

print(df2.mean(numeric_only=True))
df2.info()
# Out:
# Drain-Source On-Resistance RDS(ON) Max @VGS=2.5V (Ω)      0.022118
# Junction Temperature Tj [max] (°C)                      158.589385
# dtype: float64
# <class 'pandas.DataFrame'>
# RangeIndex: 716 entries, 0 to 715
# Data columns (total 19 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Manufacture                                           716 non-null    str
#  1   Product                                               716 non-null    str
#  2   Status                                                716 non-null    str
#  3   Compliance                                            716 non-null    str
#  4   Number of Functions                                   716 non-null    str
#  5   Channel                                               716 non-null    str
#  6   Package Type                                          716 non-null    str
# ...

# %%
df[df2['Channel']=='N+P'].head(100)
# Out:
#                            Manufacture          Product     Status Compliance  \
# 36   MCC (Micro Commercial Components)     MCGD115NP10L  Preferred        R H
# 122  MCC (Micro Commercial Components)       MCGD10NP03     Active        R H
# 270  MCC (Micro Commercial Components)    MCACD032NP06L     Active        R H
# 271  MCC (Micro Commercial Components)     MCQD028NP04L     Active        R H
# 272  MCC (Micro Commercial Components)     MCQD037NP06L     Active        R H
# 273  MCC (Micro Commercial Components)    MCACD100NP10L     Active        R H
# 274  MCC (Micro Commercial Components)      MCQ200NP10L     Active        R H
# 275  MCC (Micro Commercial Components)       MCQ03NP10L     Active        R H
# 276  MCC (Micro Commercial Components)     MCGD016NP04L     Active        R H
# 277  MCC (Micro Commercial Components)     MCGD018NP03L     Active        R H
# 278  MCC (Micro Commercial Components)      MCQ018NP03L     Active        R H
# ...
